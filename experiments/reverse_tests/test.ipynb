# %%
import pandas as pd
import sys

sys.path.append('../../src')
from utilities import print_exams

# %%
season = '2025SH'

test_result = pd.read_csv(f'/home/chenyh/workspace/fluProfiler/experiments/reverse_tests/test_result/{season}_fluProfiler.csv')

# %%
print(test_result.shape)
# Out:
# (4592, 23)

# %%
print_exams(test_result['label'], test_result['prediction'])
# Out:
# MAE: 1.14616
# MSE: 2.90935
# pearson correlation: 0.59931
# spearman correlation: 0.62313
# R2_score: 0.22203
# (1.1461647125287282,
#  2.909352105794155,
#  PearsonRResult(statistic=np.float64(0.5993110448486294), pvalue=np.float64(0.0)),
#  SignificanceResult(statistic=np.float64(0.6231282228356262), pvalue=np.float64(0.0)),
#  0.22203039160510274)
