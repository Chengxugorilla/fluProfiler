# %%
import sys
sys.path.append('../')
from utilities import load_embedding
import torch
import pandas as pd

# %%
Crick_all = pd.read_csv('../../data/data_40/all.csv')

# %%
# load embedding
sequence_names = Crick_all['seq_id_c'].unique().tolist()
sequence_names = ['matrix_' + item + '.pt' for item in sequence_names]
emb_dict = load_embedding("../../data/data_40/embedding_Crick", files=sequence_names)
# Out:
# Loading tensor: 100%|██████████| 5318/5318 [13:48<00:00,  6.42file/s]

# %%
Crick_all['seq_id_c'].unique().tolist()
# Out:
# ['HA_3',
#  'HA_1',
#  'HA_4',
#  'HA_5',
#  'HA_0',
#  'HA_2',
#  'HA_7',
#  'HA_9',
#  'HA_10',
#  'HA_6',
#  'HA_8',
#  'HA_3028',
#  'HA_2965',
#  'HA_3025',
#  'HA_77',
#  'HA_82',
#  'HA_74',
#  'HA_89',
#  'HA_76',
#  'HA_2959',
#  'HA_3027',
#  'HA_3103',
#  'HA_3104',
#  'HA_96',
#  'HA_92',
#  'HA_2935',
#  'HA_2940',
#  'HA_87',
#  'HA_78',
#  'HA_79',
#  'HA_2961',
#  'HA_2958',
#  'HA_2938',
#  'HA_2939',
#  'HA_95',
#  'HA_2937',
#  'HA_90',
#  'HA_2962',
#  'HA_3023',
#  'HA_83',
#  'HA_3024',
#  'HA_3014',
#  'HA_99',
#  'HA_3026',
#  'HA_98',
#  'HA_100',
#  'HA_3105',
#  'HA_102',
#  'HA_105',
#  'HA_2936',
#  'HA_2960',
#  'HA_3029',
#  'HA_2995',
#  'HA_3102',
#  'HA_97',
#  'HA_2957',
#  'HA_2941',
#  'HA_2963',
#  'HA_75',
#  'HA_86',
#  'HA_70',
#  'HA_73',
#  'HA_2894',
#  'HA_2891',
#  'HA_2892',
#  'HA_69',
#  'HA_67',
#  'HA_71',
#  'HA_2890',
#  'HA_72',
#  'HA_2893',
#  'HA_191',
#  'HA_5298',
#  'HA_5060',
#  'HA_4783',
#  'HA_5313',
#  'HA_196',
# ...
