# %%
import torch
torch.load('./embedding/matrix_NA_1.pt', weights_only=False)
# Out:
# array([[ 0.09378582, -0.09525497,  0.11834203, ..., -0.04268588,
#         -0.05287286,  0.17877886],
#        [ 0.03500443, -0.03333805,  0.27041522, ...,  0.0213244 ,
#         -0.255356  ,  0.10927241],
#        [ 0.076501  ,  0.0462361 ,  0.19480427, ..., -0.08039147,
#         -0.16768172,  0.0974072 ],
#        ...,
#        [ 0.18129131,  0.04149938,  0.0689514 , ..., -0.21258865,
#          0.11948261, -0.02187316],
#        [ 0.00378683, -0.07053956,  0.09277096, ..., -0.26904896,
#          0.17320797,  0.04974886],
#        [ 0.07515875, -0.01760107,  0.1385358 , ..., -0.28516674,
#          0.2582585 ,  0.0034312 ]], dtype=float32)
